# %%
 #Part 1 : Data Loading
 #1. Load the california_housing.csv file using pandas.
from sklearn.datasets import fetch_california_housing
import pandas as pd
housing = fetch_california_housing(as_frame=True)
df = housing.frame
# Now df is your full California Housing dataset!
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
#2. Display the first 5 rows.
df.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
#3. Print the column names and their data types.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
#4.. Check for missing values in the dataset.
df.isnull()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       False     False     False      False       False     False     False
# 1       False     False     False      False       False     False     False
# 2       False     False     False      False       False     False     False
# 3       False     False     False      False       False     False     False
# 4       False     False     False      False       False     False     False
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635   False     False     False      False       False     False     False
# 20636   False     False     False      False       False     False     False
# 20637   False     False     False      False       False     False     False
# 20638   False     False     False      False       False     False     False
# 20639   False     False     False      False       False     False     False
#
#        Longitude  MedHouseVal
# ...

# %%
#. Check for missing values in the dataset.
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
#5.. Get basic statistical summaries using .describe().
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
# Part 2: Data Cleaning
#6. Check for and remove any duplicated rows.
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Length: 20640, dtype: bool

# %%
#6. Check for and remove any duplicated rows.
df.duplicated().sum()
# Answer ==> There is no duplicate rows to remove. So, output is actual dataset
# Out:
# np.int64(0)

# %%
#6. Check for and remove any duplicated rows.
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
#6. Check for and remove any duplicated rows.
#Incase there were duplicates, we can use the below code
df = df.drop_duplicates()

# %%
#6. Check for and remove any duplicated rows.
#Incase there were duplicates, we can use the below code
df.reset_index(drop=True, inplace=True)

# %%
#6. Check for and remove any duplicated rows.
#Incase there were duplicates, we can use the below code
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
#7. Handle missing values if any:
# Fill missing numerical features with the mean value.
df.mean(numeric_only=True)
# Out:
# MedInc            3.870671
# HouseAge         28.639486
# AveRooms          5.429000
# AveBedrms         1.096675
# Population     1425.476744
# AveOccup          3.070655
# Latitude         35.631861
# Longitude      -119.569704
# MedHouseVal       2.068558
# dtype: float64

# %%
#7. Handle missing values if any:
# Fill missing numerical features with the mean value.
#There is no missing value in this dataset
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
#7. Handle missing values if any:
# Fill missing numerical features with the mean value.
#Incase there are missing values in a dataset, we can use the below code
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
#7. Handle missing values if any:
# Fill missing numerical features with the mean value.
#The output is the actual dataset itself
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
#8.Create a new column PricePerRoom = median_house_value / total_rooms.
#total_rooms = Average rooms * Population
df['PricePerRoom'] = df['MedHouseVal'] / (df['AveRooms'] * df['Population'])

# %%
#8.Create a new column PricePerRoom = median_house_value / total_rooms.
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal  PricePerRoom
# ...

# %%
#9. Create a column HighPopulationArea:
#  1 if population > 500, else 0.
df['HighPopulationArea'] = (df['Population'] > 500).astype(int)

# %%
#9. Create a column HighPopulationArea:
#  1 if population > 500, else 0.
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
#10. Bin the median_income into 5 equal-sized bins and label them as Very Low, Low, Medium,
#High, Very High. (Hint: pd.cut)
bins = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

df['IncomeCategory'] = pd.cut(df['MedInc'], bins=5, labels=bins)

# %%
#10. Bin the median_income into 5 equal-sized bins and label them as Very Low, Low, Medium,
#High, Very High. (Hint: pd.cut)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
#11.Drop columns that seem redundant after feature creation (if any).
#We can use this code to drop unnecessary columns
df_cleaned = df.drop(columns=['AveOccup','Latitude','Longitude','AveBedrms','housing_median_age'], inplace=False)
df_cleaned
# Out:
#        MedInc  HouseAge  AveRooms  Population  MedHouseVal  PricePerRoom  \
# 0      8.3252      41.0  6.984127       322.0        4.526      0.002013
# 1      8.3014      21.0  6.238137      2401.0        3.585      0.000239
# 2      7.2574      52.0  8.288136       496.0        3.521      0.000857
# 3      5.6431      52.0  5.817352       558.0        3.413      0.001051
# 4      3.8462      52.0  6.281853       565.0        3.422      0.000964
# ...       ...       ...       ...         ...          ...           ...
# 20635  1.5603      25.0  5.045455       845.0        0.781      0.000183
# 20636  2.5568      18.0  6.114035       356.0        0.771      0.000354
# 20637  1.7000      17.0  5.205543      1007.0        0.923      0.000176
# 20638  1.8672      18.0  5.329513       741.0        0.847      0.000214
# 20639  2.3886      16.0  5.254717      1387.0        0.894      0.000123
#
#        HighPopulationArea IncomeCategory
# 0                       0         Medium
# ...

# %%
#11.Drop columns that seem redundant after feature creation (if any).
#We can use this code to drop unnecessary columns
df_cleaned.to_csv('Reshma_Cleaned_dataset.csv', index=False)

# %%
#Part 3: Data Visualization
#12. Plot the distribution of median_house_value with a histogram.
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df['MedHouseVal'], bins=10,edgecolor='black')
plt.xlabel('Median House Value')
plt.ylabel('Frequency')
plt.title('Distribution of Median House Value')
plt.show()

# %%
# Create a scatter plot of longitude vs latitude, colored by median_house_value.
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['Longitude'], df['Latitude'], c=df['MedHouseVal'], cmap='viridis', edgecolors='k')
plt.colorbar(scatter, label='Median House Value')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot:Longitude vs Latitude colored by Median House Value')
plt.show()

# %%
#14. Plot a boxplot of median_house_value grouped by the new income categories.
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.boxplot(x='IncomeCategory', y='MedHouseVal', data=df)

plt.xlabel('Income Category')
plt.ylabel('Median House Value')
plt.title('Boxplot of Median House Value Grouped by Income Category')
plt.show()

# %%
#5. Plot the correlation matrix heatmap between numerical features.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MedInc              20640 non-null  float64
#  1   HouseAge            20640 non-null  float64
#  2   AveRooms            20640 non-null  float64
#  3   AveBedrms           20640 non-null  float64
#  4   Population          20640 non-null  float64
#  5   AveOccup            20640 non-null  float64
#  6   Latitude            20640 non-null  float64
#  7   Longitude           20640 non-null  float64
#  8   MedHouseVal         20640 non-null  float64
#  9   PricePerRoom        20640 non-null  float64
#  10  HighPopulationArea  20640 non-null  int64
#  11  IncomeCategory      20640 non-null  category
# dtypes: category(1), float64(10), int64(1)
# memory usage: 1.8 MB

# %%
#5. Plot the correlation matrix heatmap between numerical features.
df_new =  df.drop('IncomeCategory', axis=1)

# %%
#5. Plot the correlation matrix heatmap between numerical features.
df_new
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
#5. Plot the correlation matrix heatmap between numerical features.
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MedInc              20640 non-null  float64
#  1   HouseAge            20640 non-null  float64
#  2   AveRooms            20640 non-null  float64
#  3   AveBedrms           20640 non-null  float64
#  4   Population          20640 non-null  float64
#  5   AveOccup            20640 non-null  float64
#  6   Latitude            20640 non-null  float64
#  7   Longitude           20640 non-null  float64
#  8   MedHouseVal         20640 non-null  float64
#  9   PricePerRoom        20640 non-null  float64
#  10  HighPopulationArea  20640 non-null  int64
# dtypes: float64(10), int64(1)
# memory usage: 1.7 MB

# %%
#5. Plot the correlation matrix heatmap between numerical features.
import seaborn as sns
import matplotlib.pyplot as plt
corr_matrix = df_new.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#16. Create a bar plot showing average median_house_value for high population vs low
#population areas.
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
#16. Create a bar plot showing average median_house_value for high population vs low
#population areas.
avg_house_value = df.groupby('HighPopulationArea')['MedHouseVal'].mean()
avg_house_value
# Out:
# HighPopulationArea
# 0    2.048424
# 1    2.070695
# Name: MedHouseVal, dtype: float64

# %%
#16. Create a bar plot showing average median_house_value for high population vs low
#population areas.
plt.figure(figsize=(8, 6))
avg_house_value = df.groupby('HighPopulationArea')['MedHouseVal'].mean()
avg_house_value.plot(kind='bar', color='blue')
plt.xlabel('Population Category')
plt.ylabel('Average Median House Value')
plt.title('Average Median House Value for High vs Low Population Areas')
plt.legend()
plt.show()

# %%
#16.Create a pairplot (sns.pairplot) for selected features: median_income, housing_median_age,
#median_house_value.
df['housing_median_age'] = df['HouseAge'].median()
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
#16.Create a pairplot (sns.pairplot) for selected features: median_income, housing_median_age,
#median_house_value.
import seaborn as sns
import matplotlib.pyplot as plt
needed_features2 = df[['MedInc', 'HouseAge', 'MedHouseVal']]
sns.pairplot(needed_features2)
plt.show()
